# %%
from rasterio.io import DatasetReader,DatasetWriter
import rasterio
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
preprocess_raster
huc_8_id_list=['010802','011000']

for huc_8_id in huc_8_id_list:
    depth_raster=

# %%
depth_file='/home/jovyan/data/aghanghas/inundation_map/outputs/010802_201210300000_depth_map.tif'
depth_raster=rasterio.open(depth_file,')
array=depth_raster.read(1)

# %%
array[array>100]=np.nan
array[array<0]=np.nan

# %%
plt.imshow(array,cmap='pink', vmax=4)
